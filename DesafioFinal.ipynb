# %%
# !pip install sqlalchemy pymysql pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 KB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 KB 1.8 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data/dados_licencas_medicas.csv', delimiter=';', date_format='%d/%m/%Y', encoding='iso-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nome_medico         1013 non-null   object
#  1   especialidade       1013 non-null   object
#  2   motivo_licença      1013 non-null   object
#  3   id_colaborador      1013 non-null   int64
#  4   nome_colaborador    1013 non-null   object
#  5   data_nascimento     1013 non-null   object
#  6   estado_colaborador  1013 non-null   object
#  7   sexo_colaborador    1013 non-null   object
#  8   inicio_licenca      1013 non-null   object
#  9   fim_licenca         1013 non-null   object
#  10  duracao_licensa     1013 non-null   int64
#  11  idade               1013 non-null   int64
#  12  escolaridade        1013 non-null   object
#  13  salario             995 non-null    float64
#  14  qtd_filhos          1007 non-null   float64
# ...

# %%
df.head()
# Out:
#    nome_medico  especialidade                  motivo_licença  id_colaborador  \
# 0    Dr. Pedro  Clínico geral            Acidente de trabalho               2
# 1  Dr. Marcelo  Clínico geral             Acidente de trajeto               6
# 2  Dr. Gustavo  Clínico geral  Enfermidade de filhos pequenos               7
# 3    Dr. Lucas  Clínico geral                           Comum              11
# 4    Dr. Pedro  Clínico geral            Acidente de trabalho              12
#
#   nome_colaborador data_nascimento   estado_colaborador sexo_colaborador  \
# 0    Sophie Aragão      27/03/1970    Rio Grande do Sul         Feminino
# 1   Juliana da Luz      25/06/1957                Ceará         Feminino
# 2  Marina da Rocha      06/01/1978  Rio Grande do Norte         Feminino
# 3     Davi da Mota      27/09/1956            Tocantins        Masculino
# 4      Paulo Souza      09/04/1968              Roraima        Masculino
#
# ...
